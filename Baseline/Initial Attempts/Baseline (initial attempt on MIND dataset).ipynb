# %% [markdown]
# #(1)Skeleton code

# %%
import pandas as pd

# read in the news.tsv file as a DataFrame
news_df = pd.read_csv('news.tsv', sep='\t', header=None, names=['id', 'title', 'abstract', 'url', 'category', 'entities'])

# convert the IDs to strings
news_df['id'] = news_df['id'].astype(str)

# randomly sample 10 articles from the DataFrame
sampled_articles = news_df.sample(10)

# display the sampled articles
print("Here are 10 randomly sampled articles:")
print(sampled_articles[['id', 'title', 'abstract']])
print()

# prompt the user to choose which articles they're interested in
chosen_ids_str = input("Please enter the IDs of the articles you're interested in, separated by commas: ")

# convert the input string into a list of IDs
chosen_ids = [id.strip()[1:] for id in chosen_ids_str.split(',')]
print("Chosen IDs:", chosen_ids)

# filter the sampled_articles DataFrame to only include the chosen articles
chosen_articles = sampled_articles[sampled_articles['id'].isin(chosen_ids)]

# get the entities from the chosen articles
chosen_entities = set()
for entities_str in chosen_articles['entities']:
    if pd.isna(entities_str):
        continue
    entities = entities_str.split(';')
    for entity in entities:
        chosen_entities.add(entity.strip())

# recommend articles based on the chosen entities
recommended_articles = pd.DataFrame(columns=['id', 'title', 'abstract', 'score'])
for entity in chosen_entities:
    entity_articles = news_df[news_df['entities'].str.contains(entity, na=False)]
    entity_articles = entity_articles[~entity_articles['id'].isin(chosen_ids)]
    entity_articles['score'] = entity_articles['entities'].apply(lambda x: x.split(';').count(entity))
    entity_articles = entity_articles.sort_values('score', ascending=False).head(5)
    entity_articles = entity_articles[['id', 'title', 'abstract', 'score']]
    entity_articles['score'] = entity_articles['score'].apply(lambda x: f"{x} (matched on '{entity}')")
    recommended_articles = recommended_articles.append(entity_articles)

# display the recommended articles
print("Here are some articles you might be interested in:")
print(recommended_articles[['id', 'title', 'abstract', 'score']])

# %%
# !pip install scrapbook
pip install -e git+https://github.com/microsoft/recommenders/#egg=recommenders

# %%
# !pip install recommenders[examples]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: recommenders[examples] in /usr/local/lib/python3.9/dist-packages (1.1.1)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (1.3.4)
# Requirement already satisfied: pandas<2,>1.0.3 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (1.3.5)
# Requirement already satisfied: matplotlib<4,>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (3.5.3)
# Requirement already satisfied: scikit-learn<1.0.3,>=0.22.1 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (1.0.2)
# Requirement already satisfied: pandera[strategies]>=0.6.5 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (0.13.4)
# Requirement already satisfied: category-encoders<2,>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (1.3.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (2.25.1)
# Requirement already satisfied: scikit-surprise>=1.0.6 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (1.1.3)
# Requirement already satisfied: nltk<4,>=3.4 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (3.7)
# Requirement already satisfied: tqdm<5,>=4.31.1 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (4.65.0)
# Requirement already satisfied: cornac<2,>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (1.14.2)
# Requirement already satisfied: pyyaml<6,>=5.4.1 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (5.4.1)
# Requirement already satisfied: lightgbm>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (2.2.3)
# Requirement already satisfied: memory-profiler<1,>=0.54.0 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (0.61.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (1.22.4)
# Requirement already satisfied: bottleneck<2,>=1.2.1 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (1.3.7)
# Requirement already satisfied: jinja2<3.1,>=2 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (3.0.3)
# Requirement already satisfied: lightfm<2,>=1.15 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (1.16)
# Requirement already satisfied: scipy<2,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (1.10.1)
# Requirement already satisfied: numba<1,>=0.38.1 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (0.56.4)
# Requirement already satisfied: transformers<5,>=2.5.0 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (4.26.1)
# Requirement already satisfied: seaborn<1,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (0.11.2)
# Requirement already satisfied: locust<2,>=1 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (1.6.0)
# Requirement already satisfied: ipykernel<7,>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (5.3.4)
# Requirement already satisfied: azure.mgmt.cosmosdb<1,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (0.16.0)
# Requirement already satisfied: papermill<3,>=2.1.2 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (2.4.0)
# Requirement already satisfied: hyperopt<1,>=0.1.2 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (0.1.2)
# Requirement already satisfied: scrapbook<1.0.0,>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (0.5.0)
# Requirement already satisfied: jupyter<2,>=1 in /usr/local/lib/python3.9/dist-packages (from recommenders[examples]) (1.0.0)
# Requirement already satisfied: msrest>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from azure.mgmt.cosmosdb<1,>=0.8.0->recommenders[examples]) (0.7.1)
# Requirement already satisfied: msrestazure<2.0.0,>=0.4.32 in /usr/local/lib/python3.9/dist-packages (from azure.mgmt.cosmosdb<1,>=0.8.0->recommenders[examples]) (0.6.4)
# Requirement already satisfied: azure-common~=1.1 in /usr/local/lib/python3.9/dist-packages (from azure.mgmt.cosmosdb<1,>=0.8.0->recommenders[examples]) (1.1.28)
# Requirement already satisfied: statsmodels>=0.6.1 in /usr/local/lib/python3.9/dist-packages (from category-encoders<2,>=1.3.0->recommenders[examples]) (0.13.5)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from category-encoders<2,>=1.3.0->recommenders[examples]) (0.5.3)
# Requirement already satisfied: powerlaw in /usr/local/lib/python3.9/dist-packages (from cornac<2,>=1.1.2->recommenders[examples]) (1.5)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from hyperopt<1,>=0.1.2->recommenders[examples]) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from hyperopt<1,>=0.1.2->recommenders[examples]) (1.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from hyperopt<1,>=0.1.2->recommenders[examples]) (3.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.9/dist-packages (from hyperopt<1,>=0.1.2->recommenders[examples]) (4.3.3)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from ipykernel<7,>=4.6.1->recommenders[examples]) (5.7.1)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from ipykernel<7,>=4.6.1->recommenders[examples]) (7.9.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel<7,>=4.6.1->recommenders[examples]) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel<7,>=4.6.1->recommenders[examples]) (6.1.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2<3.1,>=2->recommenders[examples]) (2.1.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from jupyter<2,>=1->recommenders[examples]) (7.7.1)
# Requirement already satisfied: notebook in /usr/local/lib/python3.9/dist-packages (from jupyter<2,>=1->recommenders[examples]) (6.3.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from jupyter<2,>=1->recommenders[examples]) (6.5.4)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.9/dist-packages (from jupyter<2,>=1->recommenders[examples]) (5.4.0)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.9/dist-packages (from jupyter<2,>=1->recommenders[examples]) (6.1.0)
# Requirement already satisfied: ConfigArgParse>=1.0 in /usr/local/lib/python3.9/dist-packages (from locust<2,>=1->recommenders[examples]) (1.5.3)
# Requirement already satisfied: Flask-BasicAuth>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from locust<2,>=1->recommenders[examples]) (0.2.0)
# Requirement already satisfied: msgpack>=0.6.2 in /usr/local/lib/python3.9/dist-packages (from locust<2,>=1->recommenders[examples]) (1.0.4)
# Requirement already satisfied: Flask-Cors>=3.0.10 in /usr/local/lib/python3.9/dist-packages (from locust<2,>=1->recommenders[examples]) (3.0.10)
# Requirement already satisfied: Werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from locust<2,>=1->recommenders[examples]) (2.2.3)
# Requirement already satisfied: gevent>=20.9.0 in /usr/local/lib/python3.9/dist-packages (from locust<2,>=1->recommenders[examples]) (22.10.2)
# Requirement already satisfied: pyzmq>=16.0.2 in /usr/local/lib/python3.9/dist-packages (from locust<2,>=1->recommenders[examples]) (23.2.1)
# Requirement already satisfied: geventhttpclient>=1.4.4 in /usr/local/lib/python3.9/dist-packages (from locust<2,>=1->recommenders[examples]) (2.0.8)
# Requirement already satisfied: flask==1.1.2 in /usr/local/lib/python3.9/dist-packages (from locust<2,>=1->recommenders[examples]) (1.1.2)
# Requirement already satisfied: psutil>=5.6.7 in /usr/local/lib/python3.9/dist-packages (from locust<2,>=1->recommenders[examples]) (5.9.4)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.9/dist-packages (from flask==1.1.2->locust<2,>=1->recommenders[examples]) (8.1.3)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.9/dist-packages (from flask==1.1.2->locust<2,>=1->recommenders[examples]) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=2.2.2->recommenders[examples]) (23.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=2.2.2->recommenders[examples]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=2.2.2->recommenders[examples]) (4.39.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=2.2.2->recommenders[examples]) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=2.2.2->recommenders[examples]) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=2.2.2->recommenders[examples]) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4,>=2.2.2->recommenders[examples]) (1.4.4)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk<4,>=3.4->recommenders[examples]) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk<4,>=3.4->recommenders[examples]) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba<1,>=0.38.1->recommenders[examples]) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba<1,>=0.38.1->recommenders[examples]) (0.39.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas<2,>1.0.3->recommenders[examples]) (2022.7.1)
# Requirement already satisfied: typing-inspect>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from pandera[strategies]>=0.6.5->recommenders[examples]) (0.8.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from pandera[strategies]>=0.6.5->recommenders[examples]) (1.10.5)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.9/dist-packages (from pandera[strategies]>=0.6.5->recommenders[examples]) (1.15.0)
# Requirement already satisfied: hypothesis>=5.41.1 in /usr/local/lib/python3.9/dist-packages (from pandera[strategies]>=0.6.5->recommenders[examples]) (6.68.2)
# Requirement already satisfied: nbclient>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from papermill<3,>=2.1.2->recommenders[examples]) (0.7.2)
# Requirement already satisfied: ansiwrap in /usr/local/lib/python3.9/dist-packages (from papermill<3,>=2.1.2->recommenders[examples]) (0.8.4)
# Requirement already satisfied: nbformat>=5.1.2 in /usr/local/lib/python3.9/dist-packages (from papermill<3,>=2.1.2->recommenders[examples]) (5.7.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from papermill<3,>=2.1.2->recommenders[examples]) (0.4)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.9/dist-packages (from papermill<3,>=2.1.2->recommenders[examples]) (8.2.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->recommenders[examples]) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->recommenders[examples]) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->recommenders[examples]) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->recommenders[examples]) (2022.12.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<1.0.3,>=0.22.1->recommenders[examples]) (3.1.0)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.9/dist-packages (from scrapbook<1.0.0,>=0.5.0->recommenders[examples]) (9.0.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.9/dist-packages (from scrapbook<1.0.0,>=0.5.0->recommenders[examples]) (4.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers<5,>=2.5.0->recommenders[examples]) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers<5,>=2.5.0->recommenders[examples]) (0.13.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<5,>=2.5.0->recommenders[examples]) (0.13.2)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.9/dist-packages (from gevent>=20.9.0->locust<2,>=1->recommenders[examples]) (5.5.2)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.9/dist-packages (from gevent>=20.9.0->locust<2,>=1->recommenders[examples]) (4.6)
# Requirement already satisfied: greenlet>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from gevent>=20.9.0->locust<2,>=1->recommenders[examples]) (2.0.2)
# Requirement already satisfied: brotli in /usr/local/lib/python3.9/dist-packages (from geventhttpclient>=1.4.4->locust<2,>=1->recommenders[examples]) (1.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers<5,>=2.5.0->recommenders[examples]) (4.5.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from hypothesis>=5.41.1->pandera[strategies]>=0.6.5->recommenders[examples]) (22.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from hypothesis>=5.41.1->pandera[strategies]>=0.6.5->recommenders[examples]) (1.1.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from hypothesis>=5.41.1->pandera[strategies]>=0.6.5->recommenders[examples]) (2.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel<7,>=4.6.1->recommenders[examples]) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel<7,>=4.6.1->recommenders[examples]) (2.6.1)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel<7,>=4.6.1->recommenders[examples]) (0.18.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel<7,>=4.6.1->recommenders[examples]) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel<7,>=4.6.1->recommenders[examples]) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel<7,>=4.6.1->recommenders[examples]) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel<7,>=4.6.1->recommenders[examples]) (2.0.10)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from msrest>=0.5.0->azure.mgmt.cosmosdb<1,>=0.8.0->recommenders[examples]) (1.3.1)
# Requirement already satisfied: azure-core>=1.24.0 in /usr/local/lib/python3.9/dist-packages (from msrest>=0.5.0->azure.mgmt.cosmosdb<1,>=0.8.0->recommenders[examples]) (1.26.3)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from msrest>=0.5.0->azure.mgmt.cosmosdb<1,>=0.8.0->recommenders[examples]) (0.6.1)
# Requirement already satisfied: adal<2.0.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from msrestazure<2.0.0,>=0.4.32->azure.mgmt.cosmosdb<1,>=0.8.0->recommenders[examples]) (1.2.7)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.9/dist-packages (from nbclient>=0.2.0->papermill<3,>=2.1.2->recommenders[examples]) (5.2.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat>=5.1.2->papermill<3,>=2.1.2->recommenders[examples]) (2.16.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->scrapbook<1.0.0,>=0.5.0->recommenders[examples]) (0.19.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from typing-inspect>=0.6.0->pandera[strategies]>=0.6.5->recommenders[examples]) (1.0.0)
# Requirement already satisfied: textwrap3>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from ansiwrap->papermill<3,>=2.1.2->recommenders[examples]) (0.9.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->jupyter<2,>=1->recommenders[examples]) (3.0.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->jupyter<2,>=1->recommenders[examples]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->jupyter<2,>=1->recommenders[examples]) (3.6.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter<2,>=1->recommenders[examples]) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter<2,>=1->recommenders[examples]) (4.6.3)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter<2,>=1->recommenders[examples]) (0.2.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter<2,>=1->recommenders[examples]) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter<2,>=1->recommenders[examples]) (6.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter<2,>=1->recommenders[examples]) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter<2,>=1->recommenders[examples]) (0.7.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter<2,>=1->recommenders[examples]) (1.2.1)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter<2,>=1->recommenders[examples]) (0.17.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter<2,>=1->recommenders[examples]) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter<2,>=1->recommenders[examples]) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter<2,>=1->recommenders[examples]) (0.16.0)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.9/dist-packages (from powerlaw->cornac<2,>=1.1.2->recommenders[examples]) (1.2.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from pymongo->hyperopt<1,>=0.1.2->recommenders[examples]) (2.3.0)
# Requirement already satisfied: qtpy>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from qtconsole->jupyter<2,>=1->recommenders[examples]) (2.3.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure.mgmt.cosmosdb<1,>=0.8.0->recommenders[examples]) (2.6.0)
# Requirement already satisfied: cryptography>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure.mgmt.cosmosdb<1,>=0.8.0->recommenders[examples]) (39.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel<7,>=4.6.1->recommenders[examples]) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbclient>=0.2.0->papermill<3,>=2.1.2->recommenders[examples]) (3.1.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.0.0->ipykernel<7,>=4.6.1->recommenders[examples]) (0.2.6)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure.mgmt.cosmosdb<1,>=0.8.0->recommenders[examples]) (3.2.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.9/dist-packages (from terminado>=0.8.3->notebook->jupyter<2,>=1->recommenders[examples]) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook->jupyter<2,>=1->recommenders[examples]) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->jupyter<2,>=1->recommenders[examples]) (0.5.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure.mgmt.cosmosdb<1,>=0.8.0->recommenders[examples]) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure.mgmt.cosmosdb<1,>=0.8.0->recommenders[examples]) (2.21)

# %%
import sys
import os
import numpy as np
import zipfile
from tqdm import tqdm
import scrapbook as sb
from tempfile import TemporaryDirectory
import tensorflow as tf
tf.get_logger().setLevel('ERROR') # only show error messages

from recommenders.models.deeprec.deeprec_utils import download_deeprec_resources 
from recommenders.models.newsrec.newsrec_utils import prepare_hparams
from recommenders.models.newsrec.models.nrms import NRMSModel
from recommenders.models.newsrec.io.mind_iterator import MINDIterator
from recommenders.models.newsrec.newsrec_utils import get_mind_data_set

print("System version: {}".format(sys.version))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# System version: 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# Tensorflow version: 2.11.0

# %% [markdown]
# #(2) Set Parameters

# %%
epochs = 5
seed = 42
batch_size = 32

# Options: demo, small, large
MIND_type = 'demo'

# %% [markdown]
# #(3) Download and load data

# %%
tmpdir = TemporaryDirectory()
data_path = tmpdir.name

train_news_file = os.path.join(data_path, 'train', r'news.tsv')
train_behaviors_file = os.path.join(data_path, 'train', r'behaviors.tsv')
valid_news_file = os.path.join(data_path, 'valid', r'news.tsv')
valid_behaviors_file = os.path.join(data_path, 'valid', r'behaviors.tsv')
wordEmb_file = os.path.join(data_path, "utils", "embedding.npy")
userDict_file = os.path.join(data_path, "utils", "uid2index.pkl")
wordDict_file = os.path.join(data_path, "utils", "word_dict.pkl")
yaml_file = os.path.join(data_path, "utils", r'nrms.yaml')

mind_url, mind_train_dataset, mind_dev_dataset, mind_utils = get_mind_data_set(MIND_type)

if not os.path.exists(train_news_file):
    download_deeprec_resources(mind_url, os.path.join(data_path, 'train'), mind_train_dataset)
    
if not os.path.exists(valid_news_file):
    download_deeprec_resources(mind_url, \
                               os.path.join(data_path, 'valid'), mind_dev_dataset)
if not os.path.exists(yaml_file):
    download_deeprec_resources(r'https://recodatasets.z20.web.core.windows.net/newsrec/', \
                               os.path.join(data_path, 'utils'), mind_utils)
# Out:
# 100%|██████████| 17.0k/17.0k [00:01<00:00, 9.15kKB/s]
# 100%|██████████| 9.84k/9.84k [00:01<00:00, 5.74kKB/s]
# 100%|██████████| 95.0k/95.0k [00:13<00:00, 7.16kKB/s]

# %% [markdown]
# #(4) Create hyper-parameters

# %%
hparams = prepare_hparams(yaml_file, 
                          wordEmb_file=wordEmb_file,
                          wordDict_file=wordDict_file, 
                          userDict_file=userDict_file,
                          batch_size=batch_size,
                          epochs=epochs,
                          show_step=10)
print(hparams)
# Out:
# HParams object with values {'support_quick_scoring': True, 'dropout': 0.2, 'attention_hidden_dim': 200, 'head_num': 20, 'head_dim': 20, 'filter_num': 200, 'window_size': 3, 'vert_emb_dim': 100, 'subvert_emb_dim': 100, 'gru_unit': 400, 'type': 'ini', 'user_emb_dim': 50, 'learning_rate': 0.0001, 'optimizer': 'adam', 'epochs': 5, 'batch_size': 32, 'show_step': 10, 'title_size': 30, 'his_size': 50, 'data_format': 'news', 'npratio': 4, 'metrics': ['group_auc', 'mean_mrr', 'ndcg@5;10'], 'word_emb_dim': 300, 'model_type': 'nrms', 'loss': 'cross_entropy_loss', 'wordEmb_file': '/tmp/tmpsogykk5m/utils/embedding.npy', 'wordDict_file': '/tmp/tmpsogykk5m/utils/word_dict.pkl', 'userDict_file': '/tmp/tmpsogykk5m/utils/uid2index.pkl'}

# %% [markdown]
# (5) Train the NRMS model

# %%
iterator = MINDIterator
model = NRMSModel(hparams, iterator, seed=seed)
print(model.run_eval(valid_news_file, valid_behaviors_file))
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 0it [00:00, ?it/s]/usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 1326it [00:49, 26.82it/s]
# 2286it [1:12:58,  1.92s/it]
# 73152it [00:14, 4979.76it/s]
# {'group_auc': 0.5024, 'mean_mrr': 0.2136, 'ndcg@5': 0.2174, 'ndcg@10': 0.2846}

# %%
# %%time
model.fit(train_news_file, train_behaviors_file, valid_news_file, valid_behaviors_file)
# Out:
# step 270 , total_loss: 1.6199, data_loss: 1.5256: : 279it [29:54,  6.59s/it]

# %%
# %%time
res_syn = model.run_eval(valid_news_file, valid_behaviors_file)
print(res_syn)

# %%
sb.glue("res_syn", res_syn)
